# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import math
from math import atan2, degrees


img = cv2.imread('circulo.png')

img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

image_lower_hsv = np.array([0, 50, 50])  
image_upper_hsv = np.array([10, 250, 222])
mask_hsv = cv2.inRange(img_hsv, image_lower_hsv, image_upper_hsv)


image_lower_hsv2 = np.array([85, 100, 100])
image_upper_hsv2 = np.array([86, 255, 255])
mask_hsv2 = cv2.inRange(img_hsv, image_lower_hsv2, image_upper_hsv2)

saida = cv2.bitwise_or(mask_hsv,mask_hsv2)

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.subplot(1, 2, 2)
plt.imshow(saida, cmap="Greys_r", vmin=0, vmax=255)
plt.show()


img = cv2.imread('circulo.png')

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

image_lower_hsv = np.array([0, 50, 50])  
image_upper_hsv = np.array([10, 255, 222])


mask_hsv = cv2.inRange(img_hsv, image_lower_hsv, image_upper_hsv)

contornos, _ = cv2.findContours(saida, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) 

mask_rgb = cv2.cvtColor(saida, cv2.COLOR_GRAY2RGB) 
contornos_img = mask_rgb.copy() # Cópia da máscara para ser desenhada "por cima"

cv2.drawContours(contornos_img, contornos, -1, [255, 0, 0], 5);

plt.figure(figsize=(8,6))
plt.imshow(contornos_img);

cnt = contornos[1]  

for c in contornos:
    area = cv2.contourArea(c)
    
    M = cv2.moments(c)

    
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])

    print("centro de massa na possição: ",cx, cy, area)
  
    size = 20
    color = (128,128,0)


    cv2.line(contornos_img,(cx - size,cy),(cx + size,cy),color,5)
    cv2.line(contornos_img,(cx,cy - size),(cx, cy + size),color,5)

    font = cv2.FONT_HERSHEY_SIMPLEX
    area = cv2.contourArea(c)

    text = cy , cx , area
    origem = (cx,cy)

    cv2.putText(contornos_img, str(text), origem, font,1,(200,50,0),2,cv2.LINE_AA)
    
    print('ângulo de '+ str(round(degrees(atan2(cx,cy)))) + '°')
    
    print(text)
    
    
    
cv2.line(contornos_img,(1020,664),(177,217),color,5)    
cv2.line(contornos_img,(1020,664),(177,644),color,5)    



plt.imshow(contornos_img);
# Out:
# centro de massa na possição:  1020 664 64380.5
# ângulo de 57°
# (664, 1020, 64380.5)
# centro de massa na possição:  177 217 64183.0
# ângulo de 39°
# (217, 177, 64183.0)
